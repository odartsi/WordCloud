# %%
import os
from os import path

from wordcloud import WordCloud

d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# Read the whole text.
text = open(path.join(d,'DefensePresentation.tex')).read()

# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:


import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
#wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure()
#plt.imshow(wordcloud, interpolation="bilinear")
#plt.axis("off")
#plt.show()

# %%
from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

from wordcloud import WordCloud, STOPWORDS

d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# Read the whole text.
text = open(path.join(d, 'DefensePresentation.tex')).read()

bike_mask = np.array(Image.open(path.join(d, "bike.png")))

#for having a good quality of the image
def transform_format(val):
    if val == 0:
        return 255
    else:
        return val
    
tbike_mask = np.ndarray((bike_mask.shape[0],bike_mask.shape[1]), np.int32)

for i in range(len(bike_mask)):
    tbike_mask[i] = list(map(transform_format, bike_mask[i]))
stopwords = set(STOPWORDS)
stopwords.add("said")
wc = WordCloud(background_color="black", max_words=5000000,max_font_size=8000, mask=tbike_mask,
               stopwords=stopwords, contour_width=1, contour_color='white')

# generate word cloud
wc.generate(text)

# show
plt.figure(figsize=[20,10])
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()

# %%
idea_mask = np.array(Image.open(path.join(d, "idea.png")))
wc = WordCloud(background_color="black", max_words=5000000,max_font_size=40, mask=idea_mask,
               stopwords=stopwords, contour_width=1, contour_color='blue')

# generate word cloud
wc.generate(text)

# show
plt.figure(figsize=[20,10])
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.show()
